# %% [markdown]
# <a href="https://colab.research.google.com/github/ne0fencing/YouTube-comment-opportunity-finder-ai-agent/blob/main/YtCmntFaiAgent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Installing the necessary libraries for AI Agents
# !pip install transformers torch sentencepiece
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (4.57.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.9.0+cu126)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (0.2.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.5.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers) (2025.11.12)

# %%
# Installing the IBM Data Prep Kit transforms
# !pip install 'data-prep-toolkit-transforms[all]'
# Out:
# Requirement already satisfied: data-prep-toolkit-transforms[all] in /usr/local/lib/python3.12/dist-packages (1.1.6)
# Requirement already satisfied: data-prep-toolkit>=1.1.6 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (1.1.6)
# Requirement already satisfied: normality<=2.6.1 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (2.6.1)
# Requirement already satisfied: scancode-toolkit==32.1.0 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (32.1.0)
# Requirement already satisfied: timeout-timer==0.2.0 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (0.2.0)
# Requirement already satisfied: bs4>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (0.0.2)
# Requirement already satisfied: transformers>=4.38.2 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (4.57.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (2.2.2)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (8.3.1)
# Requirement already satisfied: httpx-sse in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (0.4.3)
# Requirement already satisfied: ibm-generative-ai in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (3.0.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (3.10.8)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (0.2.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (3.3)
# Requirement already satisfied: numpy<=1.26.4 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (1.26.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (5.24.1)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (17.0.0)
# Requirement already satisfied: streamlit in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (1.52.2)
# Requirement already satisfied: tree-sitter==0.21.3 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (0.21.3)
# Requirement already satisfied: tree-sitter-languages==1.10.2 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (1.10.2)
# Requirement already satisfied: sentence_transformers in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (5.2.0)
# Requirement already satisfied: clamd==1.0.2 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (1.0.2)
# Requirement already satisfied: colorlog==6.8.2 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (6.8.2)
# Requirement already satisfied: func-timeout==4.3.5 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (4.3.5)
# Requirement already satisfied: emerge-viz==2.0.0 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (2.0.0)
# Requirement already satisfied: pydantic>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (2.12.3)
# Requirement already satisfied: presidio-analyzer>=2.2.355 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (2.2.360)
# Requirement already satisfied: presidio-anonymizer>=2.2.355 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (2.2.360)
# Requirement already satisfied: flair>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (0.15.1)
# Requirement already satisfied: fasttext-wheel in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (0.9.2)
# Requirement already satisfied: langcodes>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (3.5.1)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.21.4 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (0.36.0)
# Requirement already satisfied: docling-core==2.50.1 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (2.50.1)
# Requirement already satisfied: docling-ibm-models in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (3.10.3)
# Requirement already satisfied: docling-parse in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (4.7.2)
# Requirement already satisfied: docling in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (2.66.0)
# Requirement already satisfied: easyocr in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (1.7.2)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (1.2.0)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.22 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (0.11.23)
# Requirement already satisfied: nltk>=3.9.1 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (3.9.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (2.32.4)
# Requirement already satisfied: polars>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (1.17.1)
# Requirement already satisfied: textstat<=0.7.5 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (0.7.5)
# Requirement already satisfied: cmudict<=1.0.32 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (1.0.32)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (6.0.3)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (6.3.1)
# Requirement already satisfied: unicategories in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (0.1.2)
# Requirement already satisfied: unicodedataplus in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (16.0.0.post1)
# Requirement already satisfied: datatrove<0.4.0 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (0.3.0)
# Requirement already satisfied: spacy in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (3.8.11)
# Requirement already satisfied: mmh3>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (5.2.0)
# Requirement already satisfied: xxhash>=3.4.1 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (3.6.0)
# Requirement already satisfied: duckdb<=1.2.2,>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (1.2.2)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (1.38.18)
# Requirement already satisfied: kubernetes>=30.1.0 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (34.1.0)
# Requirement already satisfied: disjoint-set>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (0.8.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (1.16.3)
# Requirement already satisfied: sentencepiece>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (0.2.1)
# Requirement already satisfied: torch>=2.2.2 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (2.9.0+cu126)
# Requirement already satisfied: rbloom>=1.5.2 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (1.5.4)
# Requirement already satisfied: data_prep_connector>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (0.2.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (5.9.5)
# Requirement already satisfied: GPUtil in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (1.4.0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (1.2.1)
# Requirement already satisfied: pygtrie>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (2.5.0)
# Requirement already satisfied: opensearch-py==3.0.0 in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit-transforms[all]) (3.0.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.16.0 in /usr/local/lib/python3.12/dist-packages (from docling-core==2.50.1->data-prep-toolkit-transforms[all]) (4.25.1)
# Requirement already satisfied: jsonref<2.0.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from docling-core==2.50.1->data-prep-toolkit-transforms[all]) (1.1.0)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from docling-core==2.50.1->data-prep-toolkit-transforms[all]) (0.9.0)
# Requirement already satisfied: pillow<13.0.0,>=10.0.0 in /usr/local/lib/python3.12/dist-packages (from docling-core==2.50.1->data-prep-toolkit-transforms[all]) (11.3.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from docling-core==2.50.1->data-prep-toolkit-transforms[all]) (4.15.0)
# Requirement already satisfied: typer<0.20.0,>=0.12.5 in /usr/local/lib/python3.12/dist-packages (from docling-core==2.50.1->data-prep-toolkit-transforms[all]) (0.19.2)
# Requirement already satisfied: latex2mathml<4.0.0,>=3.77.0 in /usr/local/lib/python3.12/dist-packages (from docling-core==2.50.1->data-prep-toolkit-transforms[all]) (3.78.1)
# Requirement already satisfied: wheel in /usr/local/lib/python3.12/dist-packages (from emerge-viz==2.0.0->data-prep-toolkit-transforms[all]) (0.45.1)
# Requirement already satisfied: autopep8 in /usr/local/lib/python3.12/dist-packages (from emerge-viz==2.0.0->data-prep-toolkit-transforms[all]) (2.3.2)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.12/dist-packages (from emerge-viz==2.0.0->data-prep-toolkit-transforms[all]) (15.0.1)
# Requirement already satisfied: interrogate in /usr/local/lib/python3.12/dist-packages (from emerge-viz==2.0.0->data-prep-toolkit-transforms[all]) (1.7.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from emerge-viz==2.0.0->data-prep-toolkit-transforms[all]) (1.6.1)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.12/dist-packages (from emerge-viz==2.0.0->data-prep-toolkit-transforms[all]) (3.17.0)
# Requirement already satisfied: py in /usr/local/lib/python3.12/dist-packages (from emerge-viz==2.0.0->data-prep-toolkit-transforms[all]) (1.11.0)
# Requirement already satisfied: pycodestyle in /usr/local/lib/python3.12/dist-packages (from emerge-viz==2.0.0->data-prep-toolkit-transforms[all]) (2.14.0)
# Requirement already satisfied: pylint in /usr/local/lib/python3.12/dist-packages (from emerge-viz==2.0.0->data-prep-toolkit-transforms[all]) (4.0.4)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from emerge-viz==2.0.0->data-prep-toolkit-transforms[all]) (3.2.5)
# Requirement already satisfied: python-louvain in /usr/local/lib/python3.12/dist-packages (from emerge-viz==2.0.0->data-prep-toolkit-transforms[all]) (0.16)
# Requirement already satisfied: PyDriller in /usr/local/lib/python3.12/dist-packages (from emerge-viz==2.0.0->data-prep-toolkit-transforms[all]) (2.9)
# Requirement already satisfied: pyperclip in /usr/local/lib/python3.12/dist-packages (from emerge-viz==2.0.0->data-prep-toolkit-transforms[all]) (1.11.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9.1->data-prep-toolkit-transforms[all]) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9.1->data-prep-toolkit-transforms[all]) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9.1->data-prep-toolkit-transforms[all]) (4.67.1)
# Requirement already satisfied: urllib3!=2.2.0,!=2.2.1,<3,>=1.26.19 in /usr/local/lib/python3.12/dist-packages (from opensearch-py==3.0.0->data-prep-toolkit-transforms[all]) (2.3.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from opensearch-py==3.0.0->data-prep-toolkit-transforms[all]) (2.9.0.post0)
# Requirement already satisfied: certifi>=2024.07.04 in /usr/local/lib/python3.12/dist-packages (from opensearch-py==3.0.0->data-prep-toolkit-transforms[all]) (2025.11.12)
# Requirement already satisfied: Events in /usr/local/lib/python3.12/dist-packages (from opensearch-py==3.0.0->data-prep-toolkit-transforms[all]) (0.5)
# Requirement already satisfied: Beautifulsoup4>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (4.13.5)
# Requirement already satisfied: boolean.py>=4.0 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (5.0)
# Requirement already satisfied: chardet>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (5.2.0)
# Requirement already satisfied: colorama>=0.3.9 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (0.4.6)
# Requirement already satisfied: commoncode>=31.0.3 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (32.4.0)
# Requirement already satisfied: container-inspector>=31.0.0 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (33.0.0)
# Requirement already satisfied: debian-inspector>=31.1.0 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (31.1.1)
# Requirement already satisfied: dparse2>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (0.7.0)
# Requirement already satisfied: fasteners in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (0.20)
# Requirement already satisfied: fingerprints>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (1.2.3)
# Requirement already satisfied: gemfileparser2>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (0.9.4)
# Requirement already satisfied: html5lib in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (1.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (8.7.0)
# Requirement already satisfied: intbitset>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (4.1.0)
# Requirement already satisfied: jaraco.functools in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (4.3.0)
# Requirement already satisfied: javaproperties>=0.5 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (0.8.2)
# Requirement already satisfied: jinja2>=2.7.0 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (3.1.6)
# Requirement already satisfied: jsonstreams>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (0.6.0)
# Requirement already satisfied: license-expression>=30.1.1 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (30.4.4)
# Requirement already satisfied: lxml>=4.9.2 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (6.0.2)
# Requirement already satisfied: MarkupSafe>=2.1.2 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (3.0.3)
# Requirement already satisfied: packageurl-python>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (0.17.6)
# Requirement already satisfied: packvers>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (21.5)
# Requirement already satisfied: parameter-expansion-patched>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (0.3.1)
# Requirement already satisfied: pdfminer.six>=20200101 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (20251229)
# Requirement already satisfied: pefile>=2020.1.1 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (2024.8.26)
# Requirement already satisfied: pkginfo2>=30.0.0 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (30.1.0)
# Requirement already satisfied: pip-requirements-parser>=32.0.1 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (32.0.1)
# Requirement already satisfied: pluggy>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (1.6.0)
# Requirement already satisfied: plugincode>=32.0.0 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (32.0.0)
# Requirement already satisfied: publicsuffix2 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (2.20191221)
# Requirement already satisfied: pyahocorasick>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (2.3.0)
# Requirement already satisfied: pygmars>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (1.0.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (2.19.2)
# Requirement already satisfied: pymaven-patch>=0.2.8 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (0.3.2)
# Requirement already satisfied: saneyaml>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (0.6.1)
# Requirement already satisfied: spdx-tools==0.8.2 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (0.8.2)
# Requirement already satisfied: text-unidecode>=1.0 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (1.3)
# Requirement already satisfied: toml>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (0.10.2)
# Requirement already satisfied: urlpy in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (0.5)
# Requirement already satisfied: xmltodict>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (1.0.2)
# Requirement already satisfied: typecode>=30.0.1 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (30.0.2)
# Requirement already satisfied: extractcode>=31.0.0 in /usr/local/lib/python3.12/dist-packages (from extractcode[full]>=31.0.0->scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (31.0.0)
# Requirement already satisfied: attrs>=22.1.0 in /usr/local/lib/python3.12/dist-packages (from scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (25.4.0)
# Requirement already satisfied: rdflib in /usr/local/lib/python3.12/dist-packages (from spdx-tools==0.8.2->scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (7.5.0)
# Requirement already satisfied: beartype in /usr/local/lib/python3.12/dist-packages (from spdx-tools==0.8.2->scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (0.22.9)
# Requirement already satisfied: uritools in /usr/local/lib/python3.12/dist-packages (from spdx-tools==0.8.2->scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (6.0.1)
# Requirement already satisfied: ply in /usr/local/lib/python3.12/dist-packages (from spdx-tools==0.8.2->scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (3.11)
# Requirement already satisfied: semantic-version in /usr/local/lib/python3.12/dist-packages (from spdx-tools==0.8.2->scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (2.10.0)
# Requirement already satisfied: importlib-resources>=5 in /usr/local/lib/python3.12/dist-packages (from cmudict<=1.0.32->data-prep-toolkit-transforms[all]) (6.5.2)
# Requirement already satisfied: scrapy>=2.11.2 in /usr/local/lib/python3.12/dist-packages (from data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]) (2.13.4)
# Requirement already satisfied: tldextract>=5.1.2 in /usr/local/lib/python3.12/dist-packages (from data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]) (5.3.1)
# Requirement already satisfied: python-json-logger in /usr/local/lib/python3.12/dist-packages (from data-prep-toolkit>=1.1.6->data-prep-toolkit-transforms[all]) (4.0.0)
# Requirement already satisfied: botocore<1.39.0,>=1.38.18 in /usr/local/lib/python3.12/dist-packages (from boto3->data-prep-toolkit-transforms[all]) (1.38.46)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from boto3->data-prep-toolkit-transforms[all]) (1.0.1)
# Requirement already satisfied: s3transfer<0.13.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from boto3->data-prep-toolkit-transforms[all]) (0.12.0)
# Requirement already satisfied: dill>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datatrove<0.4.0->data-prep-toolkit-transforms[all]) (0.3.8)
# Requirement already satisfied: fsspec>=2023.12.2 in /usr/local/lib/python3.12/dist-packages (from datatrove<0.4.0->data-prep-toolkit-transforms[all]) (2025.3.0)
# Requirement already satisfied: humanize in /usr/local/lib/python3.12/dist-packages (from datatrove<0.4.0->data-prep-toolkit-transforms[all]) (4.14.0)
# Requirement already satisfied: loguru>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from datatrove<0.4.0->data-prep-toolkit-transforms[all]) (0.7.3)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from datatrove<0.4.0->data-prep-toolkit-transforms[all]) (0.70.16)
# Requirement already satisfied: conllu<5.0.0,>=4.0 in /usr/local/lib/python3.12/dist-packages (from flair>=0.14.0->data-prep-toolkit-transforms[all]) (4.5.3)
# Requirement already satisfied: deprecated>=1.2.13 in /usr/local/lib/python3.12/dist-packages (from flair>=0.14.0->data-prep-toolkit-transforms[all]) (1.3.1)
# Requirement already satisfied: gdown>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from flair>=0.14.0->data-prep-toolkit-transforms[all]) (5.2.0)
# Requirement already satisfied: langdetect>=1.0.9 in /usr/local/lib/python3.12/dist-packages (from flair>=0.14.0->data-prep-toolkit-transforms[all]) (1.0.9)
# Requirement already satisfied: more-itertools>=8.13.0 in /usr/local/lib/python3.12/dist-packages (from flair>=0.14.0->data-prep-toolkit-transforms[all]) (10.8.0)
# Requirement already satisfied: mpld3>=0.3 in /usr/local/lib/python3.12/dist-packages (from flair>=0.14.0->data-prep-toolkit-transforms[all]) (0.5.12)
# Requirement already satisfied: pptree>=3.1 in /usr/local/lib/python3.12/dist-packages (from flair>=0.14.0->data-prep-toolkit-transforms[all]) (3.1)
# Requirement already satisfied: pytorch-revgrad>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from flair>=0.14.0->data-prep-toolkit-transforms[all]) (0.2.0)
# Requirement already satisfied: segtok>=1.5.11 in /usr/local/lib/python3.12/dist-packages (from flair>=0.14.0->data-prep-toolkit-transforms[all]) (1.5.11)
# Requirement already satisfied: sqlitedict>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from flair>=0.14.0->data-prep-toolkit-transforms[all]) (2.1.0)
# Requirement already satisfied: transformer-smaller-training-vocab>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from flair>=0.14.0->data-prep-toolkit-transforms[all]) (0.4.2)
# Requirement already satisfied: wikipedia-api>=0.5.7 in /usr/local/lib/python3.12/dist-packages (from flair>=0.14.0->data-prep-toolkit-transforms[all]) (0.8.1)
# Requirement already satisfied: bioc<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from flair>=0.14.0->data-prep-toolkit-transforms[all]) (2.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from ftfy->data-prep-toolkit-transforms[all]) (0.2.14)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0,>=0.21.4->data-prep-toolkit-transforms[all]) (3.20.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0,>=0.21.4->data-prep-toolkit-transforms[all]) (25.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0.0,>=0.21.4->data-prep-toolkit-transforms[all]) (1.2.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=30.1.0->data-prep-toolkit-transforms[all]) (1.17.0)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=30.1.0->data-prep-toolkit-transforms[all]) (2.43.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=30.1.0->data-prep-toolkit-transforms[all]) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.12/dist-packages (from kubernetes>=30.1.0->data-prep-toolkit-transforms[all]) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=30.1.0->data-prep-toolkit-transforms[all]) (0.10)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]) (2.0.45)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]) (3.13.2)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]) (0.6.7)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]) (1.0.8)
# Requirement already satisfied: httpx in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]) (0.27.2)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]) (1.6.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]) (8.5.0)
# Requirement already satisfied: tiktoken>=0.3.3 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]) (0.12.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]) (2.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->data-prep-toolkit-transforms[all]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->data-prep-toolkit-transforms[all]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->data-prep-toolkit-transforms[all]) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->data-prep-toolkit-transforms[all]) (1.4.9)
# Requirement already satisfied: banal>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from normality<=2.6.1->data-prep-toolkit-transforms[all]) (1.0.6)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from normality<=2.6.1->data-prep-toolkit-transforms[all]) (3.4.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->data-prep-toolkit-transforms[all]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->data-prep-toolkit-transforms[all]) (2025.3)
# Requirement already satisfied: phonenumbers<10.0.0,>=8.12 in /usr/local/lib/python3.12/dist-packages (from presidio-analyzer>=2.2.355->data-prep-toolkit-transforms[all]) (9.0.21)
# Requirement already satisfied: cryptography<44.1 in /usr/local/lib/python3.12/dist-packages (from presidio-anonymizer>=2.2.355->data-prep-toolkit-transforms[all]) (43.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.8.2->data-prep-toolkit-transforms[all]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.8.2->data-prep-toolkit-transforms[all]) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.8.2->data-prep-toolkit-transforms[all]) (0.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->data-prep-toolkit-transforms[all]) (3.11)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy->data-prep-toolkit-transforms[all]) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy->data-prep-toolkit-transforms[all]) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy->data-prep-toolkit-transforms[all]) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy->data-prep-toolkit-transforms[all]) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy->data-prep-toolkit-transforms[all]) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.12/dist-packages (from spacy->data-prep-toolkit-transforms[all]) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy->data-prep-toolkit-transforms[all]) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.12/dist-packages (from spacy->data-prep-toolkit-transforms[all]) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy->data-prep-toolkit-transforms[all]) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from spacy->data-prep-toolkit-transforms[all]) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from spacy->data-prep-toolkit-transforms[all]) (0.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from spacy->data-prep-toolkit-transforms[all]) (75.2.0)
# Requirement already satisfied: pyphen in /usr/local/lib/python3.12/dist-packages (from textstat<=0.7.5->data-prep-toolkit-transforms[all]) (0.17.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.2->data-prep-toolkit-transforms[all]) (1.14.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.2->data-prep-toolkit-transforms[all]) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.2->data-prep-toolkit-transforms[all]) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.2->data-prep-toolkit-transforms[all]) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.2->data-prep-toolkit-transforms[all]) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.2->data-prep-toolkit-transforms[all]) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.2->data-prep-toolkit-transforms[all]) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.2->data-prep-toolkit-transforms[all]) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.2->data-prep-toolkit-transforms[all]) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.2->data-prep-toolkit-transforms[all]) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.2->data-prep-toolkit-transforms[all]) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.2->data-prep-toolkit-transforms[all]) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.2->data-prep-toolkit-transforms[all]) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.2->data-prep-toolkit-transforms[all]) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.2->data-prep-toolkit-transforms[all]) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.2->data-prep-toolkit-transforms[all]) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.2->data-prep-toolkit-transforms[all]) (3.5.0)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.38.2->data-prep-toolkit-transforms[all]) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.38.2->data-prep-toolkit-transforms[all]) (0.7.0)
# Requirement already satisfied: pypdfium2!=4.30.1,<5.0.0,>=4.30.0 in /usr/local/lib/python3.12/dist-packages (from docling->data-prep-toolkit-transforms[all]) (4.30.0)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from docling->data-prep-toolkit-transforms[all]) (2.12.0)
# Requirement already satisfied: rapidocr<4.0.0,>=3.3 in /usr/local/lib/python3.12/dist-packages (from docling->data-prep-toolkit-transforms[all]) (3.4.5)
# Requirement already satisfied: rtree<2.0.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from docling->data-prep-toolkit-transforms[all]) (1.4.1)
# Requirement already satisfied: python-docx<2.0.0,>=1.1.2 in /usr/local/lib/python3.12/dist-packages (from docling->data-prep-toolkit-transforms[all]) (1.2.0)
# Requirement already satisfied: python-pptx<2.0.0,>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from docling->data-prep-toolkit-transforms[all]) (1.0.2)
# Requirement already satisfied: marko<3.0.0,>=2.1.2 in /usr/local/lib/python3.12/dist-packages (from docling->data-prep-toolkit-transforms[all]) (2.2.1)
# Requirement already satisfied: openpyxl<4.0.0,>=3.1.5 in /usr/local/lib/python3.12/dist-packages (from docling->data-prep-toolkit-transforms[all]) (3.1.5)
# Requirement already satisfied: pylatexenc<3.0,>=2.10 in /usr/local/lib/python3.12/dist-packages (from docling->data-prep-toolkit-transforms[all]) (2.10)
# Requirement already satisfied: accelerate<2,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from docling->data-prep-toolkit-transforms[all]) (1.12.0)
# Requirement already satisfied: polyfactory>=2.22.2 in /usr/local/lib/python3.12/dist-packages (from docling->data-prep-toolkit-transforms[all]) (3.2.0)
# Requirement already satisfied: torchvision<1,>=0 in /usr/local/lib/python3.12/dist-packages (from docling-ibm-models->data-prep-toolkit-transforms[all]) (0.24.0+cu126)
# Requirement already satisfied: jsonlines<5.0.0,>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from docling-ibm-models->data-prep-toolkit-transforms[all]) (4.0.0)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from easyocr->data-prep-toolkit-transforms[all]) (4.11.0.86)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from easyocr->data-prep-toolkit-transforms[all]) (0.25.2)
# Requirement already satisfied: python-bidi in /usr/local/lib/python3.12/dist-packages (from easyocr->data-prep-toolkit-transforms[all]) (0.6.7)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.12/dist-packages (from easyocr->data-prep-toolkit-transforms[all]) (2.1.2)
# Requirement already satisfied: pyclipper in /usr/local/lib/python3.12/dist-packages (from easyocr->data-prep-toolkit-transforms[all]) (1.4.0)
# Requirement already satisfied: ninja in /usr/local/lib/python3.12/dist-packages (from easyocr->data-prep-toolkit-transforms[all]) (1.13.0)
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.12/dist-packages (from fasttext-wheel->data-prep-toolkit-transforms[all]) (3.0.1)
# Requirement already satisfied: aiolimiter<2.0.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from ibm-generative-ai->data-prep-toolkit-transforms[all]) (1.2.1)
# Requirement already satisfied: traitlets in /usr/local/lib/python3.12/dist-packages (from matplotlib-inline->data-prep-toolkit-transforms[all]) (5.7.1)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit->data-prep-toolkit-transforms[all]) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from streamlit->data-prep-toolkit-transforms[all]) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit->data-prep-toolkit-transforms[all]) (6.2.4)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/lib/python3.12/dist-packages (from streamlit->data-prep-toolkit-transforms[all]) (5.29.5)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.12/dist-packages (from streamlit->data-prep-toolkit-transforms[all]) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.12/dist-packages (from streamlit->data-prep-toolkit-transforms[all]) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.12/dist-packages (from streamlit->data-prep-toolkit-transforms[all]) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /usr/local/lib/python3.12/dist-packages (from streamlit->data-prep-toolkit-transforms[all]) (6.5.1)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.12/dist-packages (from unicategories->data-prep-toolkit-transforms[all]) (1.4.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]) (1.22.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit->data-prep-toolkit-transforms[all]) (2.13.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from Beautifulsoup4>=4.0.0->scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (2.8)
# Requirement already satisfied: intervaltree in /usr/local/lib/python3.12/dist-packages (from bioc<3.0.0,>=2.0.0->flair>=0.14.0->data-prep-toolkit-transforms[all]) (3.2.1)
# Requirement already satisfied: docopt in /usr/local/lib/python3.12/dist-packages (from bioc<3.0.0,>=2.0.0->flair>=0.14.0->data-prep-toolkit-transforms[all]) (0.6.2)
# Requirement already satisfied: dockerfile-parse in /usr/local/lib/python3.12/dist-packages (from container-inspector>=31.0.0->scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (2.0.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography<44.1->presidio-anonymizer>=2.2.355->data-prep-toolkit-transforms[all]) (2.0.0)
# Requirement already satisfied: semchunk<3.0.0,>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from docling-core[chunking]<3.0.0,>=2.50.1->docling->data-prep-toolkit-transforms[all]) (2.2.2)
# Requirement already satisfied: extractcode-7z>=16.5.210525 in /usr/local/lib/python3.12/dist-packages (from extractcode[full]>=31.0.0->scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (16.5.210531)
# Requirement already satisfied: extractcode-libarchive>=3.5.1.210525 in /usr/local/lib/python3.12/dist-packages (from extractcode[full]>=31.0.0->scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (3.5.1.210531)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->data-prep-toolkit-transforms[all]) (4.0.12)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.0.1->kubernetes>=30.1.0->data-prep-toolkit-transforms[all]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=1.0.1->kubernetes>=30.1.0->data-prep-toolkit-transforms[all]) (4.9.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx->llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]) (4.12.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx->llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]) (1.0.9)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from httpx->llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]) (1.3.1)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx->llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata->scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (3.23.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.16.0->docling-core==2.50.1->data-prep-toolkit-transforms[all]) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.16.0->docling-core==2.50.1->data-prep-toolkit-transforms[all]) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0.0,>=4.16.0->docling-core==2.50.1->data-prep-toolkit-transforms[all]) (0.30.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl<4.0.0,>=3.1.5->docling->data-prep-toolkit-transforms[all]) (2.0.0)
# Requirement already satisfied: faker>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from polyfactory>=2.22.2->docling->data-prep-toolkit-transforms[all]) (40.1.0)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /usr/local/lib/python3.12/dist-packages (from python-pptx<2.0.0,>=1.0.2->docling->data-prep-toolkit-transforms[all]) (3.2.9)
# Requirement already satisfied: opencv_python>=4.5.1.48 in /usr/local/lib/python3.12/dist-packages (from rapidocr<4.0.0,>=3.3->docling->data-prep-toolkit-transforms[all]) (4.11.0.86)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.12/dist-packages (from rapidocr<4.0.0,>=3.3->docling->data-prep-toolkit-transforms[all]) (2.3.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->emerge-viz==2.0.0->data-prep-toolkit-transforms[all]) (3.6.0)
# Requirement already satisfied: cssselect>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]) (1.3.0)
# Requirement already satisfied: defusedxml>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]) (0.7.1)
# Requirement already satisfied: itemadapter>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]) (0.13.0)
# Requirement already satisfied: itemloaders>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]) (1.3.2)
# Requirement already satisfied: parsel>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]) (1.10.0)
# Requirement already satisfied: protego>=0.1.15 in /usr/local/lib/python3.12/dist-packages (from scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]) (0.5.0)
# Requirement already satisfied: pydispatcher>=2.0.5 in /usr/local/lib/python3.12/dist-packages (from scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]) (2.0.7)
# Requirement already satisfied: pyopenssl>=22.0.0 in /usr/local/lib/python3.12/dist-packages (from scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]) (24.2.1)
# Requirement already satisfied: queuelib>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]) (1.8.0)
# Requirement already satisfied: service-identity>=18.1.0 in /usr/local/lib/python3.12/dist-packages (from scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]) (24.2.0)
# Requirement already satisfied: twisted<=25.5.0,>=21.7.0 in /usr/local/lib/python3.12/dist-packages (from scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]) (25.5.0)
# Requirement already satisfied: w3lib>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]) (2.3.1)
# Requirement already satisfied: zope-interface>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]) (8.1.1)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]) (3.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.2.2->data-prep-toolkit-transforms[all]) (1.3.0)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy->data-prep-toolkit-transforms[all]) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy->data-prep-toolkit-transforms[all]) (0.1.5)
# Requirement already satisfied: requests-file>=1.4 in /usr/local/lib/python3.12/dist-packages (from tldextract>=5.1.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]) (3.0.1)
# Requirement already satisfied: binaryornot in /usr/local/lib/python3.12/dist-packages (from typecode>=30.0.1->scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (0.4.4)
# Requirement already satisfied: typecode-libmagic>=5.39.210223 in /usr/local/lib/python3.12/dist-packages (from typecode[full]>=30.0.1->scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (5.39.210531)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.20.0,>=0.12.5->docling-core==2.50.1->data-prep-toolkit-transforms[all]) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer<0.20.0,>=0.12.5->docling-core==2.50.1->data-prep-toolkit-transforms[all]) (13.9.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]) (1.1.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy->data-prep-toolkit-transforms[all]) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy->data-prep-toolkit-transforms[all]) (7.5.0)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.12/dist-packages (from coloredlogs->emerge-viz==2.0.0->data-prep-toolkit-transforms[all]) (10.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.22->data-prep-toolkit-transforms[all]) (3.26.2)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from html5lib->scancode-toolkit==32.1.0->data-prep-toolkit-transforms[all]) (0.5.1)
# Requirement already satisfied: types-pytz in /usr/local/lib/python3.12/dist-packages (from PyDriller->emerge-viz==2.0.0->data-prep-toolkit-transforms[all]) (2025.2.0.20251108)
# Requirement already satisfied: lizard in /usr/local/lib/python3.12/dist-packages (from PyDriller->emerge-viz==2.0.0->data-prep-toolkit-transforms[all]) (1.19.0)
# Requirement already satisfied: astroid<=4.1.dev0,>=4.0.2 in /usr/local/lib/python3.12/dist-packages (from pylint->emerge-viz==2.0.0->data-prep-toolkit-transforms[all]) (4.0.2)
# Requirement already satisfied: isort!=5.13,<8,>=5 in /usr/local/lib/python3.12/dist-packages (from pylint->emerge-viz==2.0.0->data-prep-toolkit-transforms[all]) (7.0.0)
# Requirement already satisfied: mccabe<0.8,>=0.6 in /usr/local/lib/python3.12/dist-packages (from pylint->emerge-viz==2.0.0->data-prep-toolkit-transforms[all]) (0.7.0)
# Requirement already satisfied: platformdirs>=2.2 in /usr/local/lib/python3.12/dist-packages (from pylint->emerge-viz==2.0.0->data-prep-toolkit-transforms[all]) (4.5.1)
# Requirement already satisfied: tomlkit>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from pylint->emerge-viz==2.0.0->data-prep-toolkit-transforms[all]) (0.13.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib->kubernetes>=30.1.0->data-prep-toolkit-transforms[all]) (3.3.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->easyocr->data-prep-toolkit-transforms[all]) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->easyocr->data-prep-toolkit-transforms[all]) (2025.12.12)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->easyocr->data-prep-toolkit-transforms[all]) (0.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography<44.1->presidio-anonymizer>=2.2.355->data-prep-toolkit-transforms[all]) (2.23)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->data-prep-toolkit-transforms[all]) (5.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=30.1.0->data-prep-toolkit-transforms[all]) (0.6.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer<0.20.0,>=0.12.5->docling-core==2.50.1->data-prep-toolkit-transforms[all]) (4.0.0)
# Requirement already satisfied: mpire[dill] in /usr/local/lib/python3.12/dist-packages (from semchunk<3.0.0,>=2.2.0->docling-core[chunking]<3.0.0,>=2.50.1->docling->data-prep-toolkit-transforms[all]) (2.10.2)
# Requirement already satisfied: automat>=24.8.0 in /usr/local/lib/python3.12/dist-packages (from twisted<=25.5.0,>=21.7.0->scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]) (25.4.16)
# Requirement already satisfied: constantly>=15.1 in /usr/local/lib/python3.12/dist-packages (from twisted<=25.5.0,>=21.7.0->scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]) (23.10.4)
# Requirement already satisfied: hyperlink>=17.1.1 in /usr/local/lib/python3.12/dist-packages (from twisted<=25.5.0,>=21.7.0->scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]) (21.0.0)
# Requirement already satisfied: incremental>=24.7.0 in /usr/local/lib/python3.12/dist-packages (from twisted<=25.5.0,>=21.7.0->scrapy>=2.11.2->data_prep_connector>=0.2.3->data-prep-toolkit-transforms[all]) (24.11.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.12/dist-packages (from intervaltree->bioc<3.0.0,>=2.0.0->flair>=0.14.0->data-prep-toolkit-transforms[all]) (2.4.0)
# Requirement already satisfied: pathspec in /usr/local/lib/python3.12/dist-packages (from lizard->PyDriller->emerge-viz==2.0.0->data-prep-toolkit-transforms[all]) (0.12.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf->rapidocr<4.0.0,>=3.3->docling->data-prep-toolkit-transforms[all]) (4.9.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown>=4.4.0->flair>=0.14.0->data-prep-toolkit-transforms[all]) (1.7.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<0.20.0,>=0.12.5->docling-core==2.50.1->data-prep-toolkit-transforms[all]) (0.1.2)

# %%
from transformers import pipeline
import re
import datetime

# This creates the 'llm' object which we will use to make decisions.
# 'text2text-generation' is the task, and flan-t5 is the brain.
llm = pipeline(
    "text2text-generation",
    model="google/flan-t5-large",
    max_length=128
)
# Out:
# Device set to use cuda:0

# %%
def reply_generator_tool(comment):
    """Generates a high-engagement reply."""
    prompt = f"Write a short, engaging YouTube reply to this: {comment}"
    response = llm(prompt)[0]["generated_text"].strip()
    return f"📝 DRAFT REPLY: {response}"

def internal_notes_tool(comment):
    """Categorizes the comment for your internal records."""
    return "📌 NOTE: This is a general comment. Saved to 'Community Sentiment' list."

def ignore_tool():
    """Filters out noise."""
    return "🗑️ ACTION: Ignore. This is likely spam or low-value."

# %%
def decide_and_act(youtube_comment):
    # This prompt 'forces' the AI to categorize the comment
    router_prompt = f"""
    Analyze the following YouTube comment: "{youtube_comment}"

    Rules:
    1. If it's a question or a request for a video, respond: TOOL_REPLY
    2. If it's a long compliment or a detailed feedback, respond: TOOL_NOTE
    3. If it's a one-word comment (like 'Nice', 'Cool') or spam, respond: TOOL_IGNORE

    Decision:
    """

    # The AI picks the tool name
    decision = llm(router_prompt)[0]["generated_text"].strip().upper()

    # Logic to execute the tool based on the AI's decision
    if "TOOL_REPLY" in decision:
        return reply_generator_tool(youtube_comment)
    elif "TOOL_NOTE" in decision:
        return internal_notes_tool(youtube_comment)
    else:
        return ignore_tool()

# %%
import pandas as pd

# Creating a messy dataset
data = {
    "comment_id": [1, 2, 3, 4, 5],
    "contents": [
        "Can you explain the IBM kit?",
        "Great video! 🔥",
        "Great video! 🔥", # Duplicate
        "Check this link out: http://spam.com",
        "How do I use Python for AI?"
    ]
}

df = pd.DataFrame(data)
# DPK often works with Parquet files for efficiency at scale
df.to_parquet("youtube_comments.parquet")
print("Messy dataset saved as Parquet.")
# Out:
# Messy dataset saved as Parquet.

# %%
# Note: In a full DPK workflow, we use their specific transform classes
# For your project, we will use the core logic discussed in the Masterclass:
def clean_youtube_data(input_df):
    # 1. Deduplication (Standard DPK practice)
    cleaned_df = input_df.drop_duplicates(subset=['contents'])

    # 2. Filtering Noise (Simulating the 'Filter' transform)
    # We remove comments that are too short to be 'opportunities'
    cleaned_df = cleaned_df[cleaned_df['contents'].str.len() > 10]

    return cleaned_df

processed_data = clean_youtube_data(df)
print(f"Original: {len(df)} comments | Cleaned: {len(processed_data)} comments")
print(processed_data)
# Out:
# Original: 5 comments | Cleaned: 4 comments
#    comment_id                              contents
# 0           1          Can you explain the IBM kit?
# 1           2                        Great video! 🔥
# 3           4  Check this link out: http://spam.com
# 4           5           How do I use Python for AI?

# %%
from transformers import pipeline
import re
import datetime

# This creates the 'llm' object which we will use to make decisions.
# 'text2text-generation' is the task, and flan-t5 is the brain.
llm = pipeline(
    "text2text-generation",
    model="google/flan-t5-large",
    max_length=128
)

def reply_generator_tool(comment):
    """Generates a high-engagement reply."""
    prompt = f"Write a short, engaging YouTube reply to this: {comment}"
    response = llm(prompt)[0]["generated_text"].strip()
    return f"📝 DRAFT REPLY: {response}"

def internal_notes_tool(comment):
    """Categorizes the comment for your internal records."""
    return "📌 NOTE: This is a general comment. Saved to 'Community Sentiment' list."

def ignore_tool():
    """Filters out noise."""
    return "🗑️ ACTION: Ignore. This is likely spam or low-value."

def decide_and_act(youtube_comment):
    # This prompt 'forces' the AI to categorize the comment
    router_prompt = f"""
    Analyze the following YouTube comment: "{youtube_comment}"

    Rules:
    1. If it's a question or a request for a video, respond: TOOL_REPLY
    2. If it's a long compliment or a detailed feedback, respond: TOOL_NOTE
    3. If it's a one-word comment (like 'Nice', 'Cool') or spam, respond: TOOL_IGNORE

    Decision:
    """

    # The AI picks the tool name
    decision = llm(router_prompt)[0]["generated_text"].strip().upper()

    # Logic to execute the tool based on the AI's decision
    if "TOOL_REPLY" in decision:
        return reply_generator_tool(youtube_comment)
    elif "TOOL_NOTE" in decision:
        return internal_notes_tool(youtube_comment)
    else:
        return ignore_tool()

print("--- YouTube Opportunity Finder Agent ---")
while True:
    user_input = input("Paste a YouTube Comment (or 'exit'): ")
    if user_input.lower() == "exit":
        print("Agent: Shutting down...")
        break

    # The agent processes the input
    result = decide_and_act(user_input)
    print(f"Agent {result}\n")
# Out:
# Device set to use cuda:0
# --- YouTube Opportunity Finder Agent ---
# Paste a YouTube Comment (or 'exit'): cool
# Agent 📝 DRAFT REPLY: I'm so glad you're here.
#
# Paste a YouTube Comment (or 'exit'): exit
# Agent: Shutting down...

# %%
import pandas as pd
import os

# Let's take our cleaned parquet data and 'send' it to a sheet
# (In a real setup, you would use the Google Sheets API)
def export_to_automation_hub(df_to_export):
    # Filter only for 'Opportunities' that need a reply
    opportunity_df = df_to_export[df_to_export['text'].str.contains('?', regex=False)]

    # Ensure the 'data' directory exists
    output_dir = "data"
    os.makedirs(output_dir, exist_ok=True)

    # Save as a CSV that we will upload to Google Sheets
    opportunity_df.to_csv(os.path.join(output_dir, "to_relay_app.csv"), index=False)
    print("🚀 Data ready for Relay.app automation!")

# Ensure the 'data' directory exists
output_dir = "data"
os.makedirs(output_dir, exist_ok=True)

# Use the existing 'cleaned_df' from the kernel state and save it to parquet
cleaned_df.to_parquet(os.path.join(output_dir, "comments_clean.parquet"))

# Now, pass the existing cleaned_df directly to the export function.
export_to_automation_hub(cleaned_df)
# Out:
# 🚀 Data ready for Relay.app automation!
